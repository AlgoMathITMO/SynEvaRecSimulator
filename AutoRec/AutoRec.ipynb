# %%
import pandas as pd
import numpy as np
import torch 
from torch.utils import data
from torch import nn

from typing import List, Tuple, Dict, Union, Optional
from typing import Iterable

# %%
from models import AutoRec, Model
from load_data import get_validation_data
from utils import Dataset

# %%
validation_data, heristic = get_validation_data()
validation_data
# Out:
#          user_0    user_1    user_2  user_id    item_0     item_1     item_2  \
# 0     -0.189219  0.688799  0.496749        0 -7.189302 -17.358819  -8.191424
# 1     -0.189219  0.688799  0.496749        0  0.749574   0.957448   2.106965
# 2     -0.189219  0.688799  0.496749        0 -3.443982  -0.042470  -1.148656
# 3     -0.189219  0.688799  0.496749        0 -1.101991  -0.047565  -0.453863
# 4     -0.189219  0.688799  0.496749        0  7.837388  18.125961  19.356996
# ...         ...       ...       ...      ...       ...        ...        ...
# 24995 -0.401447 -0.463426 -1.824159      249 -1.780516  -3.164613   0.289502
# 24996 -0.401447 -0.463426 -1.824159      249 -1.835749  -1.362072  -0.549780
# 24997 -0.401447 -0.463426 -1.824159      249 -0.900141  -0.433615   0.459035
# 24998 -0.401447 -0.463426 -1.824159      249 -1.414088   2.804230 -37.497444
# 24999 -0.401447 -0.463426 -1.824159      249  0.676129   5.459118   0.850149
#
#        item_id  rating
# 0            0     3.0
# 1            1     9.0
# 2            2     6.0
# 3            3     6.0
# 4            4     9.0
# ...        ...     ...
# 24995       95     7.0
# 24996       96     8.0
# 24997       97     6.0
# 24998       98    10.0
# 24999       99     5.0
#
# [25000 rows x 9 columns]

# %%
heristic.head()
# Out:
#    user_id  item_id  rating
# 0        0        0     9.0
# 1        0        1     8.0
# 2        0        2     8.0
# 3        0        3     8.0
# 4        0        4     6.0

# %%
data_sparse = validation_data #validation_data.sample(frac=0.05)
data_sparse = data_sparse.sample(frac=0.1)
data_train = data_sparse.sample(frac=0.8)
data_test = data_sparse.drop(data_train.index)

# %%
dataset = Dataset(data_sparse, 
                  validation_data.user_id.unique().shape[0], 
                  validation_data.item_id.unique().shape[0], 
                  user_based=True,
                  long_matrix=True,
                  user_column="user_id", item_column="item_id", rating_column="rating")

dataset_train = Dataset(data_train, 
                  validation_data.user_id.unique().shape[0], 
                  validation_data.item_id.unique().shape[0], 
                  user_based=True,
                  long_matrix=True,
                  user_column="user_id", item_column="item_id", rating_column="rating")

dataset_test = Dataset(data_test, 
                  validation_data.user_id.unique().shape[0], 
                  validation_data.item_id.unique().shape[0], 
                  user_based=True,
                  long_matrix=True,
                  user_column="user_id", item_column="item_id", rating_column="rating")

# %%
i_autorec = AutoRec(
    input_size=validation_data.item_id.unique().shape[0],
    hidden_dims=[500],
    encoder_activation_fn = nn.Sigmoid,
    decoder_activation_fn = None,
    dropout=0.05,
    bias=True
)

# %%
def init_weights(layer):
        if isinstance(layer, nn.Linear):
            torch.nn.init.xavier_normal_(layer.weight)
            layer.bias.data.fill_(0.01)

# %%
i_autorec.apply(init_weights)
# Out:
# AutoRec(
#   (encoder): Sequential(
#     (0): Linear(in_features=100, out_features=500, bias=True)
#     (1): Sigmoid()
#     (2): Dropout(p=0.05, inplace=False)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=500, out_features=100, bias=True)
#     (1): Dropout(p=0.05, inplace=False)
#   )
# )

# %%
model = Model(
    model=i_autorec,
    optimizer=torch.optim.Adam,
    optimizer_config={"lr": 0.001, "betas": (0.9, 0.999), "eps": 1e-08, "weight_decay": 0.1},
    loss_fn=nn.MSELoss(),
    batch_size=16,
    num_epoch=50,
    device=torch.device("cuda:1")
)

# %%
errors = model.train(dataset_train, 0.2, False)

# %%
model.test(dataset_test, dataset_test, with_nulls=True)
# Out:
# {'rmse': 0.5122106988226777, 'mae': 0.4924404801349251, 'ndcg': 0.0}

# %%
model.test(dataset_test)
# Out:
# {'rmse': 6.309031628960862,
#  'mae': 5.672043684005737,
#  'ndcg': 0.9273181192593506}

# %%
((i_autorec(dataset_test[:].to('cuda:1')).detach().cpu() - dataset_test[:])**2).mean().sqrt()
# Out:
# tensor(1.0263)

# %%
((model(dataset_test[:]).detach().cpu() - dataset_test[:])**2).mean().sqrt()
# Out:
# tensor(1.0263)

# %%
mtp = Dataset(validation_data, 
              validation_data.user_id.unique().shape[0], 
              validation_data.item_id.unique().shape[0], 
              user_based=True,
              long_matrix=True,
              user_column="user_id", item_column="item_id", rating_column="rating")[:].numpy()

# %%
import os
import sys
import math
import time
import numpy as np
import pandas as pd
from numpy import random as npr
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)


import importlib
sys.path.insert(0, r'../SinEvaRec/modules/')

import evaluator, trainers, utils, models
importlib.reload(models)
importlib.reload(trainers)
importlib.reload(evaluator)
importlib.reload(utils)
# Out:
# <module 'utils' from '../SinEvaRec/modules/utils.py'>

# %%
class ResponseFunction:
    def __init__(self, heu_matrix, nn_matrix, noise_matrix):
        assert heu_matrix.shape == nn_matrix.shape
        self._heu_matrix = heu_matrix
        self._nn_matrix = nn_matrix
        self._noise_matrix = noise_matrix
        
    def __call__(self, a1: float, a2: float):
        a3 = max(0.0, 1 - a1 - a2)
        
        return (
            a1 * self._heu_matrix
            + a2 * self._nn_matrix
            + a3 * npr.normal(1, 1, size=self._heu_matrix.shape)
            #to avoid identical zeros in NMF
            + 0.00001
        )

# %%
result = pd.DataFrame()
SEED = 2021
# Out:
# WARNING:root:
# DeepCTR-PyTorch version 0.2.8 detected. Your version is 0.2.7.
# Use `pip install -U deepctr-torch` to upgrade.Changelog: https://github.com/shenweichen/DeepCTR-Torch/releases/tag/v0.2.8

# %%
_resp_fn_config = evaluator.ResponseFunctionConfig(
    factory=ResponseFunction,
    args=[mtp, mtp, mtp]
)

_evaluators = [
    evaluator.TrainTestExecutorConfig(
        factory=trainers.AutoRecTrainTestExecutor,
        args={},
        model_name="autorec"
    ) 
]
        
            
for sample in [0.1, 0.5, 0.9]:
    np.random.seed(SEED)
    _evaluator = evaluator.Evaluator(_resp_fn_config, n_proc=1)
    start = time.time()
    results_ = _evaluator.evaluate(
            _evaluators, 
            a_sample_rate=2,
            test_size=0.2, 
            sample_sizes=[sample]
    )
    end = time.time()
    print('Total time: ' + str(end - start))
    result = result.append(results_)
# Out:
# Subprocess started.
# 0.0 0.0 0.1
# Load data finished. Number of users: 250 Number of items: 100
# [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456,
_DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_GPU:1, XLA_GPU, 17179869184, 6984381716595585954)]
# IAutoRec.
# -----------------------Start 1-----------------------
# -----------------------Start 2-----------------------
# -----------------------Start 3-----------------------
# -----------------------Start 4-----------------------
# -----------------------Start 5-----------------------
# Sess
# Epoch: 0000; RMSE:4.595934653956172; MAE:3.802933818761049
# Epoch: 0003; RMSE:2.89718489649451; MAE:2.2846863315718196
# Epoch: 0006; RMSE:2.631903539750014; MAE:2.218057567585063
# Epoch: 0009; RMSE:2.6021142150712766; MAE:2.2085995831382217
# Epoch: 0012; RMSE:2.579607668982971; MAE:2.173670871114939
# Epoch: 0015; RMSE:2.554735916589127; MAE:2.1787309230725382
# Epoch: 0018; RMSE:2.5166678514016647; MAE:2.1025455607402184
# Epoch: 0021; RMSE:2.481553776453028; MAE:2.0872230590285192
# Epoch: 0024; RMSE:2.4467119651806524; MAE:2.031434944035475
# Epoch: 0027; RMSE:2.3978272656961184; MAE:1.9786834028796718
# Epoch: 0030; RMSE:2.3518003811293036; MAE:1.9675403556354412
# Epoch: 0033; RMSE:2.3053059906282307; MAE:1.9038292480474157
# Epoch: 0036; RMSE:2.2556610702289177; MAE:1.852052630871833
# Epoch: 0039; RMSE:2.2129950436739683; MAE:1.7965654768662278
# Epoch: 0042; RMSE:2.177918174032163; MAE:1.8044800250493471
# Epoch: 0045; RMSE:2.1348316995366146; MAE:1.724324449223986
# Epoch: 0048; RMSE:2.095994529390182; MAE:1.6817663528299063
# Training of AutoRec
# 4.009180545806885
#
# Total time: 28.171834707260132

# %%
result
# Out:
#     a1   a2 model_name  sample_size      rmse       mae  ndcg  test_size  \
# 0  0.0  0.0    autorec          0.1  1.165427  0.937845     0        0.2
# 1  0.0  0.5    autorec          0.1  1.219253  0.925230     0        0.2
# 2  0.0  1.0    autorec          0.1  2.002342  1.418651     0        0.2
# 3  0.5  0.0    autorec          0.1  1.176155  0.898276     0        0.2
# 4  0.5  0.5    autorec          0.1  2.127704  1.530626     0        0.2
# 5  1.0  0.0    autorec          0.1  2.175486  1.541830     0        0.2
# 0  0.0  0.0    autorec          0.5  1.126800  0.903861     0        0.2
# 1  0.0  0.5    autorec          0.5  0.799066  0.578589     0        0.2
# 2  0.0  1.0    autorec          0.5  1.516574  1.117065     0        0.2
# 3  0.5  0.0    autorec          0.5  0.860904  0.592383     0        0.2
# 4  0.5  0.5    autorec          0.5  1.510021  1.045580     0        0.2
# 5  1.0  0.0    autorec          0.5  1.550431  1.137609     0        0.2
# 0  0.0  0.0    autorec          0.9  1.130915  0.910124     0        0.2
# 1  0.0  0.5    autorec          0.9  0.830409  0.592708     0        0.2
# 2  0.0  1.0    autorec          0.9  2.278729  1.837056     0        0.2
# 3  0.5  0.0    autorec          0.9  0.823655  0.590295     0        0.2
# 4  0.5  0.5    autorec          0.9  2.011460  1.583795     0        0.2
# 5  1.0  0.0    autorec          0.9  2.095995  1.681766     0        0.2
#
#         calculation_time
# 0 0 days 00:00:02.871396
# 1 0 days 00:00:02.000139
# 2 0 days 00:00:02.209847
# 3 0 days 00:00:02.091715
# 4 0 days 00:00:02.226792
# 5 0 days 00:00:02.396757
# 0 0 days 00:00:03.570258
# 1 0 days 00:00:03.114906
# 2 0 days 00:00:03.376319
# 3 0 days 00:00:03.830054
# 4 0 days 00:00:03.435431
# 5 0 days 00:00:03.408061
# 0 0 days 00:00:04.950737
# 1 0 days 00:00:04.261115
# 2 0 days 00:00:04.412258
# 3 0 days 00:00:04.279464
# 4 0 days 00:00:04.963826
# 5 0 days 00:00:04.965016

# %%
result[result.sample_size == 0.1].rmse.mean()
# Out:
# 1.644394682931338

# %%
result[result.sample_size == 0.5].rmse.mean()
# Out:
# 1.227299340684236

# %%
result[result.sample_size == 0.9].rmse.mean()
# Out:
# 1.5285269899738034

# %%
factory=trainers.AutoRecTrainTestExecutor()

# %%
long_table=trainers._rating_matrix_to_long_table(mtp)
long_table = long_table.sample(frac=0.1)

# %%
train_matrix, test_matrix, n_users, n_items = factory._transform_long_table_to_sparse_matrix(long_table, 0.2)
# Out:
# Load data finished. Number of users: 250 Number of items: 100

# %%
import typing as t
import tensorflow as tf

config = tf.compat.v1.ConfigProto() #
config.gpu_options.allow_growth = True #

# %%
with tf.compat.v1.Session() as sess:
    print(sess.list_devices())
    model = models.IAutoRec(sess, 250, 100)
    
    model.build_network()
    
    errors_log = model.execute(train_matrix, test_matrix)
    
    test = model.test(test_matrix)
# Out:
# [_DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 268435456, 7953295561788063595), _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 4340229576994145973), _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_GPU:0, XLA_GPU, 17179869184, 3600671085252589614), _DeviceAttributes(/job:localhost/replica:0/task:0/device:XLA_GPU:1, XLA_GPU, 17179869184, 13288572854706407455)]
# IAutoRec.
# -----------------------Start 1-----------------------
# -----------------------Start 2-----------------------
# -----------------------Start 3-----------------------
# -----------------------Start 4-----------------------
# -----------------------Start 5-----------------------
# Sess
# Epoch: 0000; RMSE:5.826435950667381; MAE:5.169479575604201
# Epoch: 0003; RMSE:2.642917508226645; MAE:2.269720501899719
# Epoch: 0006; RMSE:2.771911409003094; MAE:2.1794244494438173
# Epoch: 0009; RMSE:2.660479646650244; MAE:2.185828321933746
# Epoch: 0012; RMSE:2.5887458571115993; MAE:2.0988895292282104
# Epoch: 0015; RMSE:2.5773933822422297; MAE:2.0551376008987425
# Epoch: 0018; RMSE:2.551267692178211; MAE:2.002266646385193
# Epoch: 0021; RMSE:2.5122088988963998; MAE:1.9507351536750794
# Epoch: 0024; RMSE:2.4826527279191772; MAE:1.912856924533844
# Epoch: 0027; RMSE:2.410670838633515; MAE:1.8507104001045227
# Epoch: 0030; RMSE:2.3313520557820286; MAE:1.7744420595169068
# Epoch: 0033; RMSE:2.2391470150448267; MAE:1.6934539375305175
# Epoch: 0036; RMSE:2.1553593150780173; MAE:1.606244821548462
# Epoch: 0039; RMSE:2.0743353270779643; MAE:1.5301723928451538
# Epoch: 0042; RMSE:2.0105412444854047; MAE:1.467530820131302
# Epoch: 0045; RMSE:1.967478689241137; MAE:1.423314685344696
# Epoch: 0048; RMSE:1.9428094753729543; MAE:1.4037543954849243
# Training of AutoRec
# 1.4942736625671387
# RMSE:1.9362316583676855; MAE:1.3905856037139892

# %%
test
# Out:
# (1.9362316583676855, 1.3905856037139892)
